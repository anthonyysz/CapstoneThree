# %% [markdown]
# # Capstone Three: Preprocessing and Modeling

# %% [markdown]
# ## Overview

# %% [markdown]
# In the last notebook, we clean our data and made sure that it was stationary. We were able to see a clear upward trend of the population over time. To see the last notebook, click [here](https://github.com/anthonyysz/CapstoneThree/blob/master/notebooks/01%20-%20Capstone%20Three%20-%20Data%20Wrangling%20and%20EDA.ipynb).

# %% [markdown]
# ## 1. Importing our tools

# %% [markdown]
# ### 1a. Importing useful packages

# %%
#Bringing in pandas and matplotlib.pyplot
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### 1b. Importing Relevant Data

# %%
#Bringing in our clean data from the last notebook. popclean will be population data and gdpclean will be gdp data.
df = pd.read_csv('../data/clean/pop_data.csv')
df = df.set_index('date')
df.index = pd.to_datetime(df.index)

df1 = pd.read_csv('../data/clean/gdp_data.csv')
df1 = df1.set_index('date')
df1.index = pd.to_datetime(df1.index)

# %% [markdown]
# ## 2. Preprocessing our data

# %% [markdown]
# A good place to start would be to split our data up into training and testing data. Let's start with the population data and then the GDP data

# %%
train_pop = df[df.index < pd.to_datetime("2005-11-01", format='%Y-%m-%d')]
test_pop = df[df.index > pd.to_datetime("2005-11-01", format='%Y-%m-%d')]

# %%
plt.plot(train_pop['value'], color = "black")
plt.plot(test_pop['value'], color = "red")
plt.show()

# %%
train_gdp = df1[df1.index < pd.to_datetime("2005-11-01", format='%Y-%m-%d')]
test_gdp = df1[df1.index > pd.to_datetime("2005-11-01", format='%Y-%m-%d')]

# %%
plt.plot(train_gdp['value'], color = "black")
plt.plot(test_gdp['value'], color = "red")
plt.show()

# %% [markdown]
# Now, we will use all data from before November of 2005 as our training data, and all data on and since then as our testing data.

# %% [markdown]
# ## 3. Modeling

# %% [markdown]
# ### 3a. ARIMA Model

# %% [markdown]
# For the ARIMA model, I need to find 3 values for my order: p being the number of autoregressive terms, d being the number of nonseasonal differences needed for stationarity, and q being the number of lagged forecast errors in the prediction equation. I will start with the population data by finding the d value.

# %%
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf

# %%
fig,ax = plt.subplots(3,2, figsize = (10,10))

a = ax[0,0].plot(df['value']); ax[0,0].set_title('Original Series')
b = plot_acf(df['value'].values,ax=ax[0,1])

c = ax[1,0].plot(df['value'].diff()); ax[1,0].set_title('1st Difference')
d = plot_acf(df['value'].diff().dropna(),ax=ax[1,1])

e = ax[2,0].plot(df['value'].diff().diff()); ax[2,0].set_title('2nd Difference')
f = plot_acf(df['value'].diff().diff().dropna(),ax=ax[2,1])

# %% [markdown]
# Right now, I am in between 1 and 2 for the d value. I am going to create a function to find the aic and bic given a dataframe and d value, that way I can determine which will d value will yield the best results.

# %%
from statsmodels.tsa.arima.model import ARIMA
import warnings
warnings.filterwarnings("ignore")
def aic_bic(df, d):
    order_aic_bic=[]

    # Loop over p values from 0-2
    for p in range(5):
      # Loop over q values from 0-2
        for q in range(5):
            # create and fit ARMA(p,q) model
            model = ARIMA(df['value'], order=(p, d, q))
            results = model.fit()
        
            # Append order and results tuple
            order_aic_bic.append((p, q,results.aic, results.bic))
    order_df = pd.DataFrame(order_aic_bic, columns=['p', 'q', 'AIC', 'BIC'])

    print(order_df.sort_values('AIC'))
    print(order_df.sort_values('BIC'))

# %%
aic_bic(df, 1)
# Out:
#     p  q          AIC          BIC
# 24  4  4  2898.571969  2930.991039
# 23  4  3  2912.047535  2940.864486
# 19  3  4  2918.417594  2947.234545
# 18  3  3  2931.281161  2956.495993
# 22  4  2  2938.930115  2964.144947
# 21  4  1  2981.785027  3003.397740
# 20  4  0  3011.806656  3029.817250
# 17  3  2  3013.204769  3034.817482
# 11  2  1  2956.380060  2970.773747
# 10  2  0  2977.143976  2987.939242
# 4   0  4  3029.862777  3047.854886
# 9   1  4  3031.795886  3053.386418
# 8   1  3  3103.280266  3121.272376
# 2   0  2  3124.030989  3134.826255
# 7   1  2  3125.926413  3140.320101
# 3   0  3  3126.422125  3140.815813
# 6   1  1  3197.305009  3208.100275
# 1   0  1  3229.878181  3237.075025
# 0   0  0  3242.923598  3246.522020
# 5   1  0  3244.672023  3251.868867

# %% [markdown]
# We got much lower AIC and BIC values using a d value of 2, so our model will be created using the order (1, 2, 2).

# %%
model1 = ARIMA(train_pop['value'], order = (4, 2, 4))
model1fit = model1.fit()
print(model1fit.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  value   No. Observations:                  216
# Model:                 ARIMA(4, 2, 4)   Log Likelihood               -1062.748
# Date:                Fri, 02 Dec 2022   AIC                           2143.495
# Time:                        20:10:46   BIC                           2173.789
# Sample:                    01-01-1952   HQIC                          2155.737
#                          - 10-01-2005
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.2379      0.443     -0.537      0.591      -1.105       0.630
# ar.L2         -0.2435      0.440     -0.554      0.580      -1.106       0.619
# ar.L3         -0.2260      0.444     -0.509      0.611      -1.096       0.644
# ar.L4          0.7535      0.435      1.730      0.084      -0.100       1.607
# ma.L1          0.1633      0.424      0.385      0.700      -0.667       0.994
# ma.L2          0.1716      0.396      0.434      0.664      -0.604       0.947
# ma.L3          0.1336      0.390      0.342      0.732      -0.631       0.898
# ma.L4         -0.7159      0.358     -2.000      0.045      -1.417      -0.014
# sigma2      1146.7707    100.897     11.366      0.000     949.015    1344.526
# ===================================================================================
# Ljung-Box (L1) (Q):                   3.74   Jarque-Bera (JB):                 9.84
# Prob(Q):                              0.05   Prob(JB):                         0.01
# Heteroskedasticity (H):               1.04   Skew:                             0.18
# Prob(H) (two-sided):                  0.86   Kurtosis:                         3.99
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# Here, since the Ljung-Box p value is above .05, the null hypothesis is not rejected and we cannot say for sure that the residuals are uncorrelated. Additionally, however, we also reject the Heteroskedasticity null hypothesis, which means that the residuals in the forecast don't show variance over time.

# %%
y_pred_pop_arima = model1fit.get_forecast(len(test_pop.index))
y_pred_pop_arima_df = y_pred_pop_arima.conf_int(alpha = 0.05) 
y_pred_pop_arima_df['Predictions'] = model1fit.predict(start = y_pred_pop_arima_df.index[0], end = y_pred_pop_arima_df.index[-1])
y_pred_pop_arima_df.index = test_pop.index
y_pred_pop_arima_out = y_pred_pop_arima_df['Predictions'] 
plt.plot(y_pred_pop_arima_out, color='blue', label = 'ARIMA Predictions')
plt.plot(train_pop['value'], color = 'black', label = 'Train Data')
plt.plot(test_pop['value'], color = 'red', label = 'Test Data')
plt.legend()
plt.show()

# %%
import numpy as np
from sklearn.metrics import mean_squared_error

arima_pop_rmse = np.sqrt(mean_squared_error(test_pop['value'].values, y_pred_pop_arima_df['Predictions']))
print("RMSE: ",arima_pop_rmse)
# Out:
# RMSE:  2733.9273636058488

# %% [markdown]
# The ARIMA model of the population data has a root mean squared error of 3139. We will use the model with the lowest root mean squared error as our best model in the end. Now, let's follow the same steps for the GDP data.

# %%
fig,ax = plt.subplots(2,2, figsize = (10,10))

a = ax[0,0].plot(df1['value']); ax[0,0].set_title('Original Series')
b = plot_acf(df1['value'].values,ax=ax[0,1])

c = ax[1,0].plot(df1['value'].diff()); ax[1,0].set_title('1st Difference')
d = plot_acf(df1['value'].diff().dropna(),ax=ax[1,1])

# %%
aic_bic(df1, 1)
# Out:
#     p  q          AIC          BIC
# 16  3  1  3762.594075  3780.604669
# 13  2  3  3764.647828  3786.260541
# 17  3  2  3764.931784  3786.544497
# 9   1  4  3765.177777  3786.790490
# 8   1  3  3765.744457  3783.755051
# 11  2  1  3766.060896  3780.469371
# 22  4  2  3767.317120  3792.531952
# 14  2  4  3769.572237  3794.787068
# 19  3  4  3769.667583  3798.484534
# 23  4  3  3769.715109  3798.532060
# 18  3  3  3774.597418  3799.812249
# 6   1  1  3776.884713  3787.691070
# 24  4  4  3778.594069  3811.013138
# 7   1  2  3778.807333  3793.215808
# 10  2  0  3779.283972  3790.090329
# 12  2  2  3779.912748  3797.923342
# 15  3  0  3780.081117  3794.489592
# 20  4  0  3780.977330  3798.987924
# 21  4  1  3782.601544  3804.214257
# 4   0  4  3786.667711  3804.678305
# 3   0  3  3791.829295  3806.237771
# 5   1  0  3792.784772  3799.989010
# 2   0  2  3799.816567  3810.622923
# 1   0  1  3821.701375  3828.905612
# 0   0  0  3869.129349  3872.731468
#     p  q          AIC          BIC
# 11  2  1  3766.060896  3780.469371
# 16  3  1  3762.594075  3780.604669
# 8   1  3  3765.744457  3783.755051
# 13  2  3  3764.647828  3786.260541
# 17  3  2  3764.931784  3786.544497
# 9   1  4  3765.177777  3786.790490
# 6   1  1  3776.884713  3787.691070
# 10  2  0  3779.283972  3790.090329
# 22  4  2  3767.317120  3792.531952
# 7   1  2  3778.807333  3793.215808
# 15  3  0  3780.081117  3794.489592
# 14  2  4  3769.572237  3794.787068
# 12  2  2  3779.912748  3797.923342
# 19  3  4  3769.667583  3798.484534
# 23  4  3  3769.715109  3798.532060
# 20  4  0  3780.977330  3798.987924
# 18  3  3  3774.597418  3799.812249
# 5   1  0  3792.784772  3799.989010
# 21  4  1  3782.601544  3804.214257
# 4   0  4  3786.667711  3804.678305
# 3   0  3  3791.829295  3806.237771
# 2   0  2  3799.816567  3810.622923
# 24  4  4  3778.594069  3811.013138
# 1   0  1  3821.701375  3828.905612
# 0   0  0  3869.129349  3872.731468

# %%
model2 = ARIMA(train_gdp['value'], order = (3, 1, 1))
model2fit = model2.fit()
print(model2fit.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  value   No. Observations:                  216
# Model:                 ARIMA(3, 1, 1)   Log Likelihood               -1479.657
# Date:                Fri, 02 Dec 2022   AIC                           2969.313
# Time:                        20:10:52   BIC                           2986.166
# Sample:                    01-01-1952   HQIC                          2976.123
#                          - 10-01-2005
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          1.2450      0.066     18.998      0.000       1.117       1.373
# ar.L2         -0.0910      0.101     -0.901      0.368      -0.289       0.107
# ar.L3         -0.1542      0.061     -2.547      0.011      -0.273      -0.036
# ma.L1         -0.9927      0.037    -27.151      0.000      -1.064      -0.921
# sigma2      5.415e+04   4303.874     12.581      0.000    4.57e+04    6.26e+04
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.13   Jarque-Bera (JB):                12.07
# Prob(Q):                              0.71   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.13   Skew:                            -0.06
# Prob(H) (two-sided):                  0.60   Kurtosis:                         4.15
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
y_pred_gdp_arima = model2fit.get_forecast(len(test_gdp.index))
y_pred_gdp_arima_df = y_pred_gdp_arima.conf_int(alpha = 0.05) 
y_pred_gdp_arima_df["Predictions"] = model2fit.predict(start = y_pred_gdp_arima_df.index[0], end = y_pred_gdp_arima_df.index[-1])
y_pred_gdp_arima_df.index = test_gdp.index
y_pred_gdp_arima_out = y_pred_gdp_arima_df["Predictions"] 
plt.plot(y_pred_gdp_arima_out, color='blue', label = 'ARIMA Predictions')
plt.plot(train_gdp['value'], color = "black", label = 'Train Data')
plt.plot(test_gdp['value'], color = "red", label = 'Test Data')
plt.legend()
plt.show()

# %%
import numpy as np
from sklearn.metrics import mean_squared_error

arma_rmse = np.sqrt(mean_squared_error(test_gdp["value"].values, y_pred_gdp_arima_df["Predictions"]))
print("RMSE: ",arma_rmse)
# Out:
# RMSE:  2701.9642426427386
